# %%
# %matplotlib inline
import grassy

# %%
g = grassy.Grass.from_csv('input_data.csv', 'SRM 1944')
g.summary()
# Out:
# # Feature reduction assistant for metabalomics
# ### NIST Marine ESB Data Tool Development
# ### FRAMey v0.1: last update November 2017
#
# ---
#
# * Timestamp: 2017-11-18 06:50:16.614561
# * User: wpk
#
# * <a href="https://www-s.nist.gov/srmors/certificates/view_certPDF.cfm?certificate=1944" target="_blank">SRM 1944</a>
# ---
# **Figure 1:** Accuracy assessment of batch XXXXX for SRM 1944.  Values are presented as normalized coverage equivalents at the mean (dots) and 1sd (error bars) of measurements, overlaid onto the certificate value (blue line) and uncertainty (green~95% coverage, red~99% coverage).
#
# ---
# ## SRM Accuracy summary
#         Name  ID        mean       std       SRM         Measureand  \
# 0      PCB 8   0   16.100000  0.200000  SRM 1944              PCB 8
# 1      a-HCH   1    2.886667  0.407226  SRM 1944              α-HCH
# 2        HCB   2    5.153333  1.313405  SRM 1944            PCB 128
# ...
