# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# !head input_data.csv
# Out:
# Name,SRM 1944-1,SRM 1944-2,SRM 1944-3
# PCB 8,15.9,16.1,16.3
# a-HCH,3.17,2.42,3.07
# HCB,6.23,3.69,5.54
# PCB 18,51.5,53.4,48.3
# g-HCH,1.34,1.71,1.41
# b-HCH,4.84,5.37,5.22
# PCB 31,68.7,73.5,64.7
# Heptachlor,0.528,0.561,0.539
# PCB 28,79.1,79.5,72.3

# %%
df_in = pd.read_csv('input_data.csv')

# %%
from IPython.display import display, Markdown

# %%
from importlib import reload
import grassy.core as grassy
reload(grassy)

g = grassy._Grass(df_in, 'SRM 1944')

# %%
g.plot_data()
plt.show()
display(g.merge_final)
# Out:
#         Name  ID        mean       std       SRM         Measureand  \
# 0      PCB 8   0   16.100000  0.200000  SRM 1944              PCB 8
# 1      a-HCH   1    2.886667  0.407226  SRM 1944              α-HCH
# 2        HCB   2    5.153333  1.313405  SRM 1944            PCB 128
# 3        HCB   2    5.153333  1.313405  SRM 1944  Hexachlorobenzene
# 3     PCB 18   3   51.066667  2.577466  SRM 1944             PCB 18
# 6     PCB 31   6   68.966667  4.406056  SRM 1944             PCB 31
# 8     PCB 28   8   76.966667  4.046398  SRM 1944             PCB 28
# 9     PCB 52   9   76.600000  0.854400  SRM 1944             PCB 52
# 10    PCB 49  10   47.166667  0.251661  SRM 1944             PCB 49
# 11    PCB 44  11   72.300000  2.128380  SRM 1944             PCB 44
# 12    PCB 95  12   33.633333  0.665833  SRM 1944             PCB 95
# 13    PCB 66  13   57.533333  2.084067  SRM 1944             PCB 66
# 15   PCB 101  15   81.566667  7.085431  SRM 1944            PCB 101
# ...
